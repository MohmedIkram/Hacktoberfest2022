# %%
import random

class Environment(object):
    def __init__(self):
        # instantiate locations and conditions
        # 0 indicates Clean and 1 indicates Dirty
        self.locationCondition = {'A': '0', 'B': '0'}

        # randomize conditions in locations A and B
        self.locationCondition['A'] = random.randint(0, 1)
        self.locationCondition['B'] = random.randint(0, 1)


class SimpleReflexVacuumAgent(Environment):
    def __init__(self, Environment):
        print(Environment.locationCondition)
        # Instantiate performance measurement
        Score = 0
        # place vacuum at random location
        vacuumLocation = random.randint(0, 1)
        # if vacuum at A
        if vacuumLocation == 0:
            print ("Vacuum is randomly placed at Location A.")
            # and Location A is Dirty.
            if Environment.locationCondition['A'] == 1:
                print ("Location A is Dirty.")
                # suck the dirt  and mark it clean
                Environment.locationCondition['A'] = 0;
                Score += 1
                print ("Location A has been Cleaned.")
                # move to B
                print ("Moving to Location B...")
                Score -= 1
                # if B is Dirty
                if Environment.locationCondition['B'] == 1:
                    print ("Location B is Dirty.")
                    # suck and mark clean
                    Environment.locationCondition['B'] = 0;
                    Score += 1
                    print ("Location B has been Cleaned.")
            else:
                # move to B
                Score -= 1
                print ("Moving to Location B...")
                # if B is Dirty
                if Environment.locationCondition['B'] == 1:
                    print ("Location B is Dirty.")
                    # suck and mark clean
                    Environment.locationCondition['B'] = 0;
                    Score += 1
                    print ("Location B has been Cleaned.")

        elif vacuumLocation == 1:
            print ("Vacuum randomly placed at Location B.")
            # and B is Dirty
            if Environment.locationCondition['B'] == 1:
                print ("Location B is Dirty.")
                # suck and mark clean
                Environment.locationCondition['B'] = 0;
                Score += 1
                print ("Location B has been Cleaned.")
                # move to A
                Score -= 1
                print ("Moving to Location A...")
                # if A is Dirty
                if Environment.locationCondition['A'] == 1:
                    print ("Location A is Dirty.")
                    # suck and mark clean
                    Environment.locationCondition['A'] = 0;
                    Score += 1
                    print ("Location A has been Cleaned.")
            else:
                # move to A
                print ("Moving to Location A...")
                Score -= 1
                # if A is Dirty
                if Environment.locationCondition['A'] == 1:
                    print ("Location A is Dirty.")
                    # suck and mark clean
                    Environment.locationCondition['A'] = 0;
                    Score += 1
                    print ("Location A has been Cleaned.")
        # done cleaning
        print (Environment.locationCondition)
        print ("Performance Measurement: " + str(Score))


theEnvironment = Environment()
theVacuum = SimpleReflexVacuumAgent(theEnvironment)
# Out:
# {'A': 1, 'B': 0}
# Vacuum randomly placed at Location B.
# Moving to Location A...
# Location A is Dirty.
# Location A has been Cleaned.
# {'A': 0, 'B': 0}
# Performance Measurement: 0

# %% [markdown]
# # Vacum Cleaner

# %% [markdown]
# # simple reflex agent

# %%
import random
room_location = ['a','b']
dirt_list = [0,1]
dirt_value = random.choice(dirt_list)
vacum_location = ''
start_point = input("From which room You want to start the cleaning:_ ")
vacum_location = random.choice(room_location)
print("\n>>>>.................>>>.................>>>..........................\n>>>>>........"+\
      "...................................................<<<<<<<<<<<<<>>>>>>>>>>>>>>>>>\n\n")
if start_point =='a':  # for partition a  outer if
    if dirt_value == 0:
        print("\nyour room ",start_point," is already clean :(\)")
        print("\nChecking Room 2:\n..................................................\n.....................\n............"+
              "..........................")
        
        dirt_value = random.choice(dirt_list)
        if dirt_value == 0:
            print("\nyour room 'b' is already clean :(\)")
        else:
            print("\nyour room 'b' is now cleaning............................\n.............................."+
                  "..................... is Clean Now :(\)")
        
    else:
        dirt_value = 0
        print("\nyour dirt room ",start_point," is now clean: :) ")
        print("\nChecking Room 2:\n..................................................\n.....................\n............"+
              "..........................")
        
        dirt_value = random.choice(dirt_list)
        if dirt_value == 0:
            print("\nyour room 'b' is already clean :(\)")
        else:
            print("\nyour room 'b' is now cleaning............................\n.............................."+
                  "..................... is Clean Now :(\)")
        
else: # for b 
    if dirt_value == 0:
        print("\nyour room ",start_point," is already clean :(\)")
        print("\nChecking Room 1:\n..................................................\n.....................\n............"+
              "..........................")
        
        dirt_value = random.choice(dirt_list)
        if dirt_value == 0:
            print("\nyour room 'b' is already clean :(\)")
        else:
            print("\nyour room 'b' is now cleaning............................\n.............................."+
                  "..................... is Clean Now :(\)")
        
    else:
        dirt_value = 0
        print("\nyour dirt room ",start_point," is now clean: :) ")
        print("\nChecking Room 1:\n..................................................\n.....................\n............"+
              "...................................... ")
        
        dirt_value = random.choice(dirt_list)
        if dirt_value == 0:
            print("\nyour room 'b' is already clean :(\)")
        else:
            print("\nyour room 'b' is now cleaning............................\n.............................."+
                  "..................... \n is Clean Now :(\)")
# Out:
# From which room You want to start the cleaning:_ b
#
# >>>>.................>>>.................>>>..........................
# >>>>>...........................................................<<<<<<<<<<<<<>>>>>>>>>>>>>>>>>
#
#
#
# your room  b  is already clean :(\)
#
# Checking Room 1:
# ..................................................
# .....................
# ......................................
#
# your room 'b' is now cleaning............................
# ................................................... is Clean Now :(\)

# %% [markdown]
# # Numpy

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-7dd3504c366f> in <module>
# ----> 1 import pandas as pd
#
# E:\Anaconda-3\lib\site-packages\pandas\__init__.py in <module>
#     177
#     178 from pandas.util._tester import test
# --> 179 import pandas.testing
#     180 import pandas.arrays
#     181
#
# E:\Anaconda-3\lib\site-packages\pandas\testing.py in <module>
#       3 """
#       4
# ----> 5 from pandas._testing import (
#       6     assert_extension_array_equal,
#       7     assert_frame_equal,
#
# E:\Anaconda-3\lib\site-packages\pandas\_testing.py in <module>
#    3052
#    3053
# -> 3054 cython_table = pd.core.base.SelectionMixin._cython_table.items()
#    3055
#    3056
#
# AttributeError: partially initialized module 'pandas' has no attribute 'core' (most likely due to a circular import)

# %%
dat = {
    "Rehman_Family": ['Haseeb','Faheem'],
    "Barazai_Family": ['Umar','Ahmad'],
    "Tajak_Family":["mehmoood shab"]
}
data_frame = pd.DataFrame(data=dat)
print(data_frame)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-381f81df4ae1> in <module>
#       4     "Tajak_Family":["mehmoood shab"]
#       5 }
# ----> 6 data_frame = pd.DataFrame(data=dat)
#       7 print(data_frame)
#
# E:\Anaconda-3\lib\site-packages\numpy\__init__.py in __getattr__(attr)
#     301                 return Tester
#     302
# --> 303             raise AttributeError("module {!r} has no attribute "
#     304                                  "{!r}".format(__name__, attr))
#     305
#
# AttributeError: module 'numpy' has no attribute 'DataFrame'

# %%
import random   #to get random value at runtime
location=input("Enter the location of room either A or B:")
room_condition_for_A= random.randint(0,1)  #1 means dirty and 0 means clean
print("A",room_condition_for_A)
room_condition_for_B= random.randint(0,1)
print("B",room_condition_for_B)
# print("The room location "+location,"\n")

if location.lower()== "a":
    
    if room_condition_for_A==0:
        print("The room location "+location+" is already clean")
        print("\nMoving to location B....\n")
        
        
        if room_condition_for_B==0:
            print("The room location B is already clean\n")
            print("The whole room is cleaned now")
            
        else:
            print("The location B is dirty,clean it")
            print("The location B is clean now\n")
            print("The whole room is cleaned now")
            
               
    if room_condition_for_A==1:
        print("The room location "+str(location)+" is dirty,clean it and then move")
        print("Room location "+str(location)+" is cleaned now\n")
        print("\nMoving to location B....\n")
        
        if room_condition_for_B==0:
            print("\nThe room location B is already clean\n")
            print("\nThe whole room is cleaned now")
            
        else:
            print("The location B is dirty,clean it")
            print("The location B is clean now\n")
            print("\nThe whole room is cleaned now")

    
elif location.lower()=="B":
    
    if room_condition_for_B==0:
        print("The room location "+str(location)+" is already clean\n")
        print("\nMoving to location A....")
        
        if room_condition_for_A==0:
            print("The room location B is already clean\n")
            print("The whole room is cleaned now")
        else:
            print("The location A is dirty,clean it")
            print("The location A is clean now\n")
            print("The whole room is cleaned now")
            
        
    if room_condition_for_B==1:
        print("\nThe room location "+str(location)+" is dirty,clean it and then move\n")
        print("Room location "+str(location)+" is cleaned now\n")
        print("Moving to location A....\n")
        
        if room_condition_for_A==0:
            print("\nThe room location A is already clean\n")
            print("\nThe whole room is cleaned now")
            
        else:
            print("The location A is dirty,clean it")
            print("The location A is clean now\n")
            print("\nThe whole room is cleaned now")
            
            
else:
    print("wrong")
# Out:
# Enter the location of room either A or B:a
# A 1
# B 0
# The room location a is dirty,clean it and then move
# Room location a is cleaned now
#
#
# Moving to location B....
#
#
# The room location B is already clean
#
#
# The whole room is cleaned now
